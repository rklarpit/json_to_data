# %% [markdown]
# This Jupyter notebook is a testing ground for the given problem and shows the values each function will return. Note the notebook is modified to not use the dbtools package and also read from the json provided as a file

# %%
import json
from flatten_json import flatten
from jsonpath import jsonpath as jp
# Not using the DB class so DB will be a nonetype object
DB =None

def parse_json(json_data):
    """
    This function will parse the given json body in the API call
    It will return a blueprint of the data which will aid in creating and loading tables
    :param json_data: json data passed in the API call
    :return: a dictionary consisting of the following:-
             1. data type of the columns against each table
             2. list of table names
             3. columns available in each table
             4. values of each column in tha API call for each table
             5. relationship of tables with each other

    """
    with open(json_data, encoding='utf-8', errors='ignore') as json_data:
        data = json.load(json_data, strict=False)
    #data = json.loads(json_data)
    flattened_data = flatten(data, separator='.')
    data_type_data = {}
    tables_list = set()
    table_column ={}
    table_values = {}
    parent_child_tables = {}
    for key, value in flattened_data.items():
        if '.' in key:
            # Finding the list of different tables
            if not key.split('.')[-2].isnumeric():
                tables = key.split('.')[-2]
                is_list = False
            else:
                tables = key.split('.')[-3]
                is_list = True
            tables_list.add(tables)
            # Enlisting columns for each table
            if not table_column.get(tables):
                table_column[tables] = set()
            table_column[tables].add(key.split('.')[-1])
            # Enlisting the values for each column and their data types against each table
            if not table_values.get(tables):
                if not is_list:
                    table_values[tables] = {}
                    data_type_data[tables] = {}
                else:
                    table_values[tables] = [{}]*len(jp(data,'$.{key}'.format(key='.'.join(key.split('.')[0:-3]))))
                    data_type_data[tables] =  [{}]*len(jp(data,'$.{key}'.format(key='.'.join(key.split('.')[0:-3]))))
            if not is_list:
                table_values[tables].update({key.split('.')[-1]: value})
                data_type_data[tables].update({key.split('.')[-1]: type(value)})
            else:
                table_values[tables][int(key.split('.')[-2])].update({key.split('.')[-1]: value})
                data_type_data[tables][int(key.split('.')[-2])].update({key.split('.')[-1]: type(value)})
            # Relation tables have with each other
            if not parent_child_tables.get(tables):
                parent_child_tables[tables] = set()
            try:
                if not is_list:
                    parent_child_tables[tables].add(key.split('.')[-3])
                else:
                    parent_child_tables[tables].add(key.split('.')[-4])
            except:
                pass
    return {
            'data_type_data': data_type_data,
            'tables_list': tables_list,
            'table_column': table_column,
            'table_values': table_values,
            'parent_child_tables': parent_child_tables
            }


def create_load_automated_tables(DB, json_data):
    """
    This function will be used to create automated tables and insert values into them
    :param DB: An object of the DB tools class
    :param json_data: json data passed in the API call
    """
    # Parse the json and get a blueprint
    meta_parse_json = parse_json(json_data)
    # Iterate over the table list from the meta data received and perform creation and insertion funcions
    for table in meta_parse_json['tables_list']:
        table_name = table
        table_columns = ''
        column_names = ''
        # Build create table queries for tables that have dictionary values in the provided json
        if isinstance(meta_parse_json['data_type_data'][table_name], dict):
            for key, value in meta_parse_json['data_type_data'][table_name].items():
                new_column = '"' + key + '"' + ' ' + return_datatype_for_postgres(value) + ',  '
                table_columns += new_column
        # Build create table queries for tables that have list values in the provided json
        elif isinstance(meta_parse_json['data_type_data'][table_name], list):
            for key, value in meta_parse_json['data_type_data'][table_name][0].items():
                new_column = '"' + key + '"' + ' ' + return_datatype_for_postgres(value) + ',  '
                table_columns += new_column
        # create the given table
        create_sql(DB, table_name, table_columns)
        params = {}
        table_columns = ''
        # Build the insert queries for the tables which have dictionary values
        if isinstance(meta_parse_json['table_values'][table_name], dict):
            for key, value in meta_parse_json['table_values'][table_name].items():
                table_columns += '"' + key + '",'
                column_names += '%(' + key + ')s,'
                params[key] = value if value else None
            insert_sql(DB, table_name, table_columns, column_names, params)
        # Build the insert queries for the tables which have an array of values
        elif isinstance(meta_parse_json['table_values'][table_name], list):
            for item in meta_parse_json['table_values'][table_name]:
                for key, value in item.items():
                    table_columns += '"' + key + '",'
                    column_names += '%(' + key + ')s,'
                    params[key] = value if value else None
                insert_sql(DB, table_name, table_columns, column_names, params)


def return_datatype_for_postgres(datatype):
    """
    convert a python data type to one that postgres can understand in the create queries
    :param datatype: python data type
    :return: postgres data type
    """
    data_type = datatype.__name__
    if datatype == 'datetime':
        data_type = 'timestamp'
    elif data_type == 'int':
        data_type = 'bigint'
    elif data_type == 'dict':
        data_type = 'json'
    else:
        data_type = 'str'
    return data_type


def create_sql(DB, table_name, table_columns):
    """
    This will help build the create table sql and execute it
    :param DB: An object of the DB tools class
    :param table_name: name of the table to be created
    :param table_columns: string of table column names along with their data type
    """
    create_sql = '''
                         CREATE TABLE IF NOT EXISTS
                         "{table_name}"
                         ({table_columns}
                         );
                    '''.format(table_name=table_name,
                               table_columns=table_columns,
                               )
    #DB.execute_sql(create_sql)
    print(create_sql)


def insert_sql(DB, table_name, table_columns, column_names, params):
    """

    :param DB: An object of the DB tools class
    :param table_name: name of the table to which values will be inserted
    :param table_columns: name of the columns in the tables
    :param column_names: its a parameterized format of the column names which will help in executing the sql
    :param params: a dictionary consisting of values to be inserted against its column names
    """
    insert_sql = '''
                    INSERT INTO 
                        "{table_name}"
                    ({table_columns})
                    VALUES
                    ({column_names})
                 '''.format(table_name=table_name,
                            table_columns=table_columns,
                            column_names=column_names)
    #DB.execute_sql(insert_sql, params)
    print(insert_sql%params)

# %%
meta_parse_json = parse_json('sample.json')

# %%
# List of tables in the given Json
meta_parse_json['tables_list']
# Out:
# {'company',
#  'contacts',
#  'object',
#  'payment_methods',
#  'pm',
#  'portfolio',
#  'property',
#  'settings',
#  'state'}

# %%
#List of columns in the given tables. Stored as a dictionary
meta_parse_json['table_column']
# Out:
# {'object': {'access_instructions',
#   'category',
#   'category_id',
#   'created_at',
#   'creator_id',
#   'data',
#   'description',
#   'enter_permission',
#   'estimate',
#   'estimate_note',
#   'flow_type',
#   'future_schedule_date',
#   'has_access_instructions',
#   'is_emergency',
#   'is_mandatory',
#   'is_resident_responsible',
#   'is_tenant_caused',
#   'is_urgent',
#   'is_vacant',
#   'issue_id',
#   'job_id',
#   'job_rating',
#   'location_id',
#   'max_cost',
#   'max_cost_hard',
#   'name',
#   'needs_help',
#   'order_number',
#   'owner_slug',
#   'pm_id',
#   'problem_id',
#   'property_id',
#   'pw_id',
#   'rating_comments',
#   'ref_job_id',
#   'ref_service_request_id',
#   'scheduled_end',
#   'scheduled_start',
#   'slug',
#   'source',
#   'state_id',
#   'state_instance_id',
#   'state_updated_at',
#   'summary',
#   'tenant_id',
#   'tenant_slug',
#   'updated_at',
#   'use_scheduler',
#   'vendor',
#   'vendor_description',
#   'vendor_id',
#   'vendor_locked_in',
#   'vendor_name',
#   'vendor_pm_relation',
#   'vendor_rating'},
#  'state': {'description', 'flow_type', 'is_visible', 'name', 'state_id'},
#  'property': {'address1',
#   'address2',
#   'address_label',
#   'address_review_status',
#   'address_status',
#   'address_status_user_id',
#   'address_validation_last_update',
#   'city',
#   'created_at',
#   'critical_note',
#   'default_access_instructions',
#   'default_notification_group_id',
#   'emergency_max_cost_hard',
#   'emergency_max_cost_soft',
#   'escalation_contact_list',
#   'escalation_failed_email_list',
#   'geo_lat',
#   'geo_lon',
#   'inherits_vendor_priorities',
#   'is_active',
#   'job_contact_group',
#   'lcn_opt_out',
#   'lcn_payment_method_id',
#   'max_cost_hard',
#   'max_cost_soft',
#   'no_access_instructions',
#   'owner_id',
#   'pm_id',
#   'portfolio_id',
#   'property_id',
#   'pw_building_id',
#   'pw_unit_id',
#   'ref_property_id',
#   'ref_unit_id',
#   'state',
#   'timezone',
#   'troubleshooting_flow_id',
#   'updated_at',
#   'use_default_automation',
#   'warranty',
#   'zip'},
#  'pm': {'availability',
#   'avatar_url',
#   'created_at',
#   'critical_note',
#   'email_enabled',
#   'has_g_token',
#   'has_payment_method',
#   'is_active',
#   'name',
#   'pw_id',
#   'ref_user_id',
#   'role_id',
#   'sms_enabled',
#   'st_cid',
#   'st_status',
#   'updated_at',
#   'user_id',
#   'user_type'},
#  'contacts': {'contact_id',
#   'created_at',
#   'is_primary',
#   'is_textable',
#   'is_valid',
#   'method',
#   'opted_out',
#   'type',
#   'updated_at',
#   'user_id',
#   'value'},
#  'company': {'address1',
#   'address2',
#   'ar',
#   'city',
#   'company_id',
#   'company_type',
#   'created_at',
#   'creator_id',
#   'critical_note',
#   'email_template_id',
#   'is_active',
#   'job_count',
#   'logo_url',
#   'name',
#   'portal_color',
#   'primary_user_id',
#   'referral_code',
#   'referral_company_id',
#   'review_url',
#   'site_url',
#   'state',
#   'timezone',
#   'updated_at',
#   'zip'},
#  'settings': {'assigned_number',
#   'created_at',
#   'default_access_instructions',
#   'default_notification_group_id',
#   'disable_property_creation',
#   'disable_tenant_creation',
#   'emergency_max_cost_hard',
#   'emergency_max_cost_soft',
#   'emergency_temp_high',
#   'emergency_temp_high_disabilities',
#   'emergency_temp_low',
#   'emergency_temp_low_disabilities',
#   'escalation_contact_list',
#   'escalation_failed_email_list',
#   'has_3rd_party_integration',
#   'has_pw_integration',
#   'integration_app_slug',
#   'invoice_email',
#   'invoice_recipient',
#   'job_contact_group',
#   'lcn_payment_method_id',
#   'max_cost_hard',
#   'max_cost_soft',
#   'onboard_step',
#   'ops_id',
#   'pm_company_id',
#   'pm_company_settings_id',
#   'send_invoice',
#   'slug',
#   'subscription_payment_method_id',
#   'troubleshooting_flow_id',
#   'updated_at',
#   'use_default_automation'},
#  'payment_methods': {'created_at',
#   'delete_reason',
#   'deleted_at',
#   'description',
#   'exp_month',
#   'exp_year',
#   'is_primary',
#   'last_four',
#   'latchel_fingerprint',
#   'payment_method_id',
#   'processor',
#   'relation_id',
#   'relation_type',
#   'status',
#   'type',
#   'updated_at'},
#  'portfolio': {'created_at',
#   'default_access_instructions',
#   'default_notification_group_id',
#   'emergency_max_cost_hard',
#   'emergency_max_cost_soft',
#   'escalation_contact_list',
#   'escalation_failed_email_list',
#   'inherits_vendor_priorities',
#   'job_contact_group',
#   'lcn_opt_out',
#   'lcn_payment_method_id',
#   'max_cost_hard',
#   'max_cost_soft',
#   'name',
#   'no_access_instructions',
#   'owner_id',
#   'pm',
#   'pm_company_id',
#   'pm_id',
#   'portfolio_id',
#   'property_count',
#   'troubleshooting_flow_id',
#   'updated_at',
#   'use_default_automation'}}

# %%
# Datatypes of the given columns based on their values in each table
meta_parse_json['data_type_data']
# Out:
# {'object': {'job_id': int,
#   'order_number': str,
#   'name': str,
#   'property_id': int,
#   'tenant_id': int,
#   'vendor_id': NoneType,
#   'pm_id': int,
#   'state_id': int,
#   'use_scheduler': int,
#   'description': str,
#   'max_cost': int,
#   'estimate': NoneType,
#   'estimate_note': NoneType,
#   'scheduled_start': NoneType,
#   'created_at': str,
#   'updated_at': str,
#   'job_rating': NoneType,
#   'vendor_rating': NoneType,
#   'rating_comments': NoneType,
#   'creator_id': int,
#   'enter_permission': int,
#   'scheduled_end': NoneType,
#   'state_instance_id': str,
#   'needs_help': int,
#   'is_urgent': int,
#   'vendor_description': str,
#   'future_schedule_date': NoneType,
#   'is_vacant': int,
#   'access_instructions': NoneType,
#   'has_access_instructions': int,
#   'category_id': NoneType,
#   'flow_type': str,
#   'is_emergency': int,
#   'pw_id': NoneType,
#   'state_updated_at': str,
#   'data': NoneType,
#   'ref_job_id': NoneType,
#   'source': str,
#   'ref_service_request_id': NoneType,
#   'slug': str,
#   'is_mandatory': int,
#   'summary': NoneType,
#   'vendor_locked_in': NoneType,
#   'is_tenant_caused': NoneType,
#   'issue_id': int,
#   'problem_id': NoneType,
#   'location_id': NoneType,
#   'is_resident_responsible': NoneType,
#   'owner_slug': str,
#   'tenant_slug': str,
#   'vendor_name': NoneType,
#   'max_cost_hard': int,
#   'vendor_pm_relation': NoneType,
#   'category': NoneType,
#   'vendor': NoneType},
#  'state': {'state_id': int,
#   'name': str,
#   'description': NoneType,
#   'is_visible': int,
#   'flow_type': str},
#  'property': {'property_id': int,
#   'address1': str,
#   'address2': NoneType,
#   'city': str,
#   'state': str,
#   'zip': str,
#   'timezone': str,
#   'pm_id': int,
#   'created_at': str,
#   'updated_at': str,
#   'critical_note': NoneType,
#   'pw_building_id': NoneType,
#   'pw_unit_id': NoneType,
#   'portfolio_id': int,
#   'escalation_contact_list': NoneType,
#   'escalation_failed_email_list': NoneType,
#   'job_contact_group': NoneType,
#   'ref_property_id': NoneType,
#   'ref_unit_id': NoneType,
#   'emergency_max_cost_soft': NoneType,
#   'emergency_max_cost_hard': NoneType,
#   'is_active': int,
#   'owner_id': int,
#   'max_cost_soft': NoneType,
#   'max_cost_hard': NoneType,
#   'geo_lat': str,
#   'geo_lon': str,
#   'use_default_automation': int,
#   'default_access_instructions': NoneType,
#   'no_access_instructions': NoneType,
#   'warranty': NoneType,
#   'default_notification_group_id': NoneType,
#   'inherits_vendor_priorities': bool,
#   'lcn_payment_method_id': NoneType,
#   'lcn_opt_out': int,
#   'troubleshooting_flow_id': NoneType,
#   'address_label': NoneType,
#   'address_status': NoneType,
#   'address_review_status': NoneType,
#   'address_status_user_id': NoneType,
#   'address_validation_last_update': NoneType},
#  'pm': {'user_id': int,
#   'user_type': str,
#   'name': str,
#   'created_at': str,
#   'updated_at': str,
#   'sms_enabled': int,
#   'email_enabled': int,
#   'critical_note': str,
#   'role_id': int,
#   'availability': NoneType,
#   'pw_id': NoneType,
#   'avatar_url': NoneType,
#   'ref_user_id': NoneType,
#   'is_active': int,
#   'st_cid': NoneType,
#   'st_status': NoneType,
#   'has_payment_method': bool,
#   'has_g_token': bool},
#  'contacts': [{'is_primary': int,
#    'user_id': int,
#    'contact_id': int,
#    'method': str,
#    'value': str,
#    'is_valid': int,
#    'created_at': str,
#    'updated_at': str,
#    'is_textable': NoneType,
#    'type': NoneType,
#    'opted_out': int}],
#  'company': {'company_id': int,
#   'name': str,
#   'created_at': str,
#   'updated_at': str,
#   'company_type': str,
#   'critical_note': NoneType,
#   'address1': str,
#   'address2': NoneType,
#   'city': str,
#   'state': str,
#   'zip': str,
#   'timezone': str,
#   'site_url': NoneType,
#   'is_active': int,
#   'referral_company_id': NoneType,
#   'review_url': NoneType,
#   'portal_color': NoneType,
#   'logo_url': NoneType,
#   'email_template_id': NoneType,
#   'primary_user_id': int,
#   'creator_id': NoneType,
#   'job_count': int,
#   'referral_code': str,
#   'ar': NoneType},
#  'settings': {'pm_company_settings_id': int,
#   'pm_company_id': int,
#   'send_invoice': int,
#   'invoice_recipient': NoneType,
#   'invoice_email': NoneType,
#   'ops_id': NoneType,
#   'slug': str,
#   'created_at': str,
#   'updated_at': str,
#   'assigned_number': NoneType,
#   'escalation_contact_list': NoneType,
#   'escalation_failed_email_list': NoneType,
#   'job_contact_group': NoneType,
#   'integration_app_slug': NoneType,
#   'emergency_max_cost_soft': NoneType,
#   'emergency_max_cost_hard': NoneType,
#   'troubleshooting_flow_id': NoneType,
#   'onboard_step': NoneType,
#   'subscription_payment_method_id': NoneType,
#   'lcn_payment_method_id': int,
#   'max_cost_soft': NoneType,
#   'max_cost_hard': NoneType,
#   'use_default_automation': int,
#   'disable_property_creation': int,
#   'default_access_instructions': NoneType,
#   'default_notification_group_id': NoneType,
#   'disable_tenant_creation': int,
#   'emergency_temp_high': NoneType,
#   'emergency_temp_low': NoneType,
#   'emergency_temp_high_disabilities': NoneType,
#   'emergency_temp_low_disabilities': NoneType,
#   'has_pw_integration': bool,
#   'has_3rd_party_integration': bool},
#  'payment_methods': [{'payment_method_id': int,
#    'relation_id': int,
#    'relation_type': str,
#    'type': str,
#    'last_four': str,
#    'is_primary': NoneType,
#    'created_at': str,
#    'updated_at': str,
#    'description': NoneType,
#    'processor': str,
#    'status': str,
#    'exp_month': NoneType,
#    'exp_year': NoneType,
#    'deleted_at': NoneType,
#    'delete_reason': NoneType,
#    'latchel_fingerprint': NoneType}],
#  'portfolio': {'portfolio_id': int,
#   'owner_id': NoneType,
#   'pm_id': NoneType,
#   'name': str,
#   'created_at': str,
#   'updated_at': str,
#   'pm_company_id': int,
#   'escalation_contact_list': NoneType,
#   'escalation_failed_email_list': NoneType,
#   'job_contact_group': NoneType,
#   'emergency_max_cost_soft': NoneType,
#   'emergency_max_cost_hard': NoneType,
#   'lcn_payment_method_id': NoneType,
#   'max_cost_soft': NoneType,
#   'max_cost_hard': NoneType,
#   'use_default_automation': int,
#   'default_access_instructions': NoneType,
#   'no_access_instructions': NoneType,
#   'default_notification_group_id': NoneType,
#   'inherits_vendor_priorities': bool,
#   'lcn_opt_out': int,
#   'troubleshooting_flow_id': NoneType,
#   'property_count': int,
#   'pm': NoneType}}

# %%
# Values that goes in each column against each table
meta_parse_json['table_values']
# Out:
# {'object': {'job_id': 20,
#   'order_number': '2-20',
#   'name': 'dfafds',
#   'property_id': 6,
#   'tenant_id': 51,
#   'vendor_id': None,
#   'pm_id': 2,
#   'state_id': 3,
#   'use_scheduler': 1,
#   'description': 'bing bong',
#   'max_cost': 332,
#   'estimate': None,
#   'estimate_note': None,
#   'scheduled_start': None,
#   'created_at': '2020-09-04 23:37:39',
#   'updated_at': '2020-09-05 02:02:07',
#   'job_rating': None,
#   'vendor_rating': None,
#   'rating_comments': None,
#   'creator_id': 1,
#   'enter_permission': 0,
#   'scheduled_end': None,
#   'state_instance_id': '43ms2',
#   'needs_help': 0,
#   'is_urgent': 0,
#   'vendor_description': 'fdgsgsffdadfggfsd fgsf dgsgf dsgdfs',
#   'future_schedule_date': None,
#   'is_vacant': 0,
#   'access_instructions': None,
#   'has_access_instructions': 0,
#   'category_id': None,
#   'flow_type': 'job',
#   'is_emergency': 0,
#   'pw_id': None,
#   'state_updated_at': '2020-09-04 23:37:39',
#   'data': None,
#   'ref_job_id': None,
#   'source': 'Internal Web Form',
#   'ref_service_request_id': None,
#   'slug': 'MMS8y',
#   'is_mandatory': 0,
#   'summary': None,
#   'vendor_locked_in': None,
#   'is_tenant_caused': None,
#   'issue_id': 9,
#   'problem_id': None,
#   'location_id': None,
#   'is_resident_responsible': None,
#   'owner_slug': 'PO-MMS8y',
#   'tenant_slug': 'T-MMS8y',
#   'vendor_name': None,
#   'max_cost_hard': 300,
#   'vendor_pm_relation': None,
#   'category': None,
#   'vendor': None},
#  'state': {'state_id': 3,
#   'name': 'Finding Vendor',
#   'description': None,
#   'is_visible': 1,
#   'flow_type': 'job'},
#  'property': {'property_id': 6,
#   'address1': '101 Sanford Farm Shpg Center',
#   'address2': None,
#   'city': 'Amsterdam',
#   'state': 'NY',
#   'zip': '12010',
#   'timezone': 'America/New_York',
#   'pm_id': 2,
#   'created_at': '2020-09-04 13:43:54',
#   'updated_at': '2020-09-04 13:43:54',
#   'critical_note': None,
#   'pw_building_id': None,
#   'pw_unit_id': None,
#   'portfolio_id': 3,
#   'escalation_contact_list': None,
#   'escalation_failed_email_list': None,
#   'job_contact_group': None,
#   'ref_property_id': None,
#   'ref_unit_id': None,
#   'emergency_max_cost_soft': None,
#   'emergency_max_cost_hard': None,
#   'is_active': 1,
#   'owner_id': 31,
#   'max_cost_soft': None,
#   'max_cost_hard': None,
#   'geo_lat': '42.9643352',
#   'geo_lon': '-74.1836972',
#   'use_default_automation': 1,
#   'default_access_instructions': None,
#   'no_access_instructions': None,
#   'warranty': None,
#   'default_notification_group_id': None,
#   'inherits_vendor_priorities': True,
#   'lcn_payment_method_id': None,
#   'lcn_opt_out': 0,
#   'troubleshooting_flow_id': None,
#   'address_label': None,
#   'address_status': None,
#   'address_review_status': None,
#   'address_status_user_id': None,
#   'address_validation_last_update': None},
#  'pm': {'user_id': 2,
#   'user_type': 'pm',
#   'name': 'Will Gordon',
#   'created_at': '2020-09-04 13:43:34',
#   'updated_at': '2020-09-04 23:55:13',
#   'sms_enabled': 1,
#   'email_enabled': 1,
#   'critical_note': 'Dolorum iure suscipit qui.',
#   'role_id': 3,
#   'availability': None,
#   'pw_id': None,
#   'avatar_url': None,
#   'ref_user_id': None,
#   'is_active': 1,
#   'st_cid': None,
#   'st_status': None,
#   'has_payment_method': True,
#   'has_g_token': False},
#  'contacts': [{'is_primary': 1,
#    'user_id': 2,
#    'contact_id': 3,
#    'method': 'email',
#    'value': 'pm@latchel.com',
#    'is_valid': 1,
#    'created_at': '2020-09-04 13:43:34',
#    'updated_at': '2020-09-04 13:43:34',
#    'is_textable': None,
#    'type': None,
#    'opted_out': 0}],
#  'company': {'company_id': 1,
#   'name': 'Gordon Test Co.',
#   'created_at': '2020-09-04 13:43:34',
#   'updated_at': '2020-09-04 13:43:34',
#   'company_type': 'pm',
#   'critical_note': None,
#   'address1': '1818 State Route 3',
#   'address2': None,
#   'city': 'Fulton',
#   'state': 'NY',
#   'zip': '13069',
#   'timezone': 'America/New_York',
#   'site_url': None,
#   'is_active': 1,
#   'referral_company_id': None,
#   'review_url': None,
#   'portal_color': None,
#   'logo_url': None,
#   'email_template_id': None,
#   'primary_user_id': 2,
#   'creator_id': None,
#   'job_count': 17,
#   'referral_code': 'cJinsNucsB',
#   'ar': None},
#  'settings': {'pm_company_settings_id': 1,
#   'pm_company_id': 1,
#   'send_invoice': 1,
#   'invoice_recipient': None,
#   'invoice_email': None,
#   'ops_id': None,
#   'slug': 'gordon-test-co-',
#   'created_at': '2020-09-04 13:43:34',
#   'updated_at': '2020-09-04 13:43:34',
#   'assigned_number': None,
#   'escalation_contact_list': None,
#   'escalation_failed_email_list': None,
#   'job_contact_group': None,
#   'integration_app_slug': None,
#   'emergency_max_cost_soft': None,
#   'emergency_max_cost_hard': None,
#   'troubleshooting_flow_id': None,
#   'onboard_step': None,
#   'subscription_payment_method_id': None,
#   'lcn_payment_method_id': 1,
#   'max_cost_soft': None,
#   'max_cost_hard': None,
#   'use_default_automation': 1,
#   'disable_property_creation': 0,
#   'default_access_instructions': None,
#   'default_notification_group_id': None,
#   'disable_tenant_creation': 0,
#   'emergency_temp_high': None,
#   'emergency_temp_low': None,
#   'emergency_temp_high_disabilities': None,
#   'emergency_temp_low_disabilities': None,
#   'has_pw_integration': False,
#   'has_3rd_party_integration': False},
#  'payment_methods': [{'payment_method_id': 1,
#    'relation_id': 1,
#    'relation_type': 'Latchel\\Company',
#    'type': 'card',
#    'last_four': '7519',
#    'is_primary': None,
#    'created_at': '2020-09-04 13:43:34',
#    'updated_at': '2020-09-04 13:43:34',
#    'description': None,
#    'processor': 'stripe',
#    'status': 'approved',
#    'exp_month': None,
#    'exp_year': None,
#    'deleted_at': None,
#    'delete_reason': None,
#    'latchel_fingerprint': None}],
#  'portfolio': {'portfolio_id': 3,
#   'owner_id': None,
#   'pm_id': None,
#   'name': 'eos',
#   'created_at': '2020-09-04 13:43:51',
#   'updated_at': '2020-09-04 13:43:51',
#   'pm_company_id': 1,
#   'escalation_contact_list': None,
#   'escalation_failed_email_list': None,
#   'job_contact_group': None,
#   'emergency_max_cost_soft': None,
#   'emergency_max_cost_hard': None,
#   'lcn_payment_method_id': None,
#   'max_cost_soft': None,
#   'max_cost_hard': None,
#   'use_default_automation': 1,
#   'default_access_instructions': None,
#   'no_access_instructions': None,
#   'default_notification_group_id': None,
#   'inherits_vendor_priorities': True,
#   'lcn_opt_out': 0,
#   'troubleshooting_flow_id': None,
#   'property_count': 5,
#   'pm': None}}

# %%
# Relationship between each tables. Note set() means its a root table
meta_parse_json['parent_child_tables']
# Out:
# {'object': set(),
#  'state': {'object'},
#  'property': {'object'},
#  'pm': {'object', 'property'},
#  'contacts': {'pm'},
#  'company': {'object', 'pm'},
#  'settings': {'company'},
#  'payment_methods': {'company'},
#  'portfolio': {'property'}}

# %%
# executing the various create and insert queries
create_load_automated_tables(DB, 'sample.json')
# Out:
#                          CREATE TABLE IF NOT EXISTS
#                          "contacts"
#                          ("is_primary" bigint,  "user_id" bigint,  "contact_id" bigint,  "method" str,  "value" str,  "is_valid" bigint,  "created_at" str,  "updated_at" str,  "is_textable" str,  "type" str,  "opted_out" bigint,
#                          );
#
#
#                     INSERT INTO
#                         "contacts"
#                     ("is_primary","user_id","contact_id","method","value","is_valid","created_at","updated_at","is_textable","type","opted_out",)
#                     VALUES
#                     (1,2,3,email,pm@latchel.com,1,2020-09-04 13:43:34,2020-09-04 13:43:34,None,None,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "pm"
#                          ("user_id" bigint,  "user_type" str,  "name" str,  "created_at" str,  "updated_at" str,  "sms_enabled" bigint,  "email_enabled" bigint,  "critical_note" str,  "role_id" bigint,  "availability" str,  "pw_id" str,  "avatar_url" str,  "ref_user_id" str,  "is_active" bigint,  "st_cid" str,  "st_status" str,  "has_payment_method" str,  "has_g_token" str,
#                          );
#
#
#                     INSERT INTO
#                         "pm"
#                     ("user_id","user_type","name","created_at","updated_at","sms_enabled","email_enabled","critical_note","role_id","availability","pw_id","avatar_url","ref_user_id","is_active","st_cid","st_status","has_payment_method","has_g_token",)
#                     VALUES
#                     (2,pm,Will Gordon,2020-09-04 13:43:34,2020-09-04 23:55:13,1,1,Dolorum iure suscipit qui.,3,None,None,None,None,1,None,None,True,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "object"
#                          ("job_id" bigint,  "order_number" str,  "name" str,  "property_id" bigint,  "tenant_id" bigint,  "vendor_id" str,  "pm_id" bigint,  "state_id" bigint,  "use_scheduler" bigint,  "description" str,  "max_cost" bigint,  "estimate" str,  "estimate_note" str,  "scheduled_start" str,  "created_at" str,  "updated_at" str,  "job_rating" str,  "vendor_rating" str,  "rating_comments" str,  "creator_id" bigint,  "enter_permission" bigint,  "scheduled_end" str,  "state_instance_id" str,  "needs_help" bigint,  "is_urgent" bigint,  "vendor_description" str,  "future_schedule_date" str,  "is_vacant" bigint,  "access_instructions" str,  "has_access_instructions" bigint,  "category_id" str,  "flow_type" str,  "is_emergency" bigint,  "pw_id" str,  "state_updated_at" str,  "data" str,  "ref_job_id" str,  "source" str,  "ref_service_request_id" str,  "slug" str,  "is_mandatory" bigint,  "summary" str,  "vendor_locked_in" str,  "is_tenant_caused" str,  "issue_id" bigint,  "problem_id" str,  "location_id" str,  "is_resident_responsible" str,  "owner_slug" str,  "tenant_slug" str,  "vendor_name" str,  "max_cost_hard" bigint,  "vendor_pm_relation" str,  "category" str,  "vendor" str,
#                          );
#
#
#                     INSERT INTO
#                         "object"
#                     ("job_id","order_number","name","property_id","tenant_id","vendor_id","pm_id","state_id","use_scheduler","description","max_cost","estimate","estimate_note","scheduled_start","created_at","updated_at","job_rating","vendor_rating","rating_comments","creator_id","enter_permission","scheduled_end","state_instance_id","needs_help","is_urgent","vendor_description","future_schedule_date","is_vacant","access_instructions","has_access_instructions","category_id","flow_type","is_emergency","pw_id","state_updated_at","data","ref_job_id","source","ref_service_request_id","slug","is_mandatory","summary","vendor_locked_in","is_tenant_caused","issue_id","problem_id","location_id","is_resident_responsible","owner_slug","tenant_slug","vendor_name","max_cost_hard","vendor_pm_relation","category","vendor",)
#                     VALUES
#                     (20,2-20,dfafds,6,51,None,2,3,1,bing bong,332,None,None,None,2020-09-04 23:37:39,2020-09-05 02:02:07,None,None,None,1,None,None,43ms2,None,None,fdgsgsffdadfggfsd fgsf dgsgf dsgdfs,None,None,None,None,None,job,None,None,2020-09-04 23:37:39,None,None,Internal Web Form,None,MMS8y,None,None,None,None,9,None,None,None,PO-MMS8y,T-MMS8y,None,300,None,None,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "property"
#                          ("property_id" bigint,  "address1" str,  "address2" str,  "city" str,  "state" str,  "zip" str,  "timezone" str,  "pm_id" bigint,  "created_at" str,  "updated_at" str,  "critical_note" str,  "pw_building_id" str,  "pw_unit_id" str,  "portfolio_id" bigint,  "escalation_contact_list" str,  "escalation_failed_email_list" str,  "job_contact_group" str,  "ref_property_id" str,  "ref_unit_id" str,  "emergency_max_cost_soft" str,  "emergency_max_cost_hard" str,  "is_active" bigint,  "owner_id" bigint,  "max_cost_soft" str,  "max_cost_hard" str,  "geo_lat" str,  "geo_lon" str,  "use_default_automation" bigint,  "default_access_instructions" str,  "no_access_instructions" str,  "warranty" str,  "default_notification_group_id" str,  "inherits_vendor_priorities" str,  "lcn_payment_method_id" str,  "lcn_opt_out" bigint,  "troubleshooting_flow_id" str,  "address_label" str,  "address_status" str,  "address_review_status" str,  "address_status_user_id" str,  "address_validation_last_update" str,
#                          );
#
#
#                     INSERT INTO
#                         "property"
#                     ("property_id","address1","address2","city","state","zip","timezone","pm_id","created_at","updated_at","critical_note","pw_building_id","pw_unit_id","portfolio_id","escalation_contact_list","escalation_failed_email_list","job_contact_group","ref_property_id","ref_unit_id","emergency_max_cost_soft","emergency_max_cost_hard","is_active","owner_id","max_cost_soft","max_cost_hard","geo_lat","geo_lon","use_default_automation","default_access_instructions","no_access_instructions","warranty","default_notification_group_id","inherits_vendor_priorities","lcn_payment_method_id","lcn_opt_out","troubleshooting_flow_id","address_label","address_status","address_review_status","address_status_user_id","address_validation_last_update",)
#                     VALUES
#                     (6,101 Sanford Farm Shpg Center,None,Amsterdam,NY,12010,America/New_York,2,2020-09-04 13:43:54,2020-09-04 13:43:54,None,None,None,3,None,None,None,None,None,None,None,1,31,None,None,42.9643352,-74.1836972,1,None,None,None,None,True,None,None,None,None,None,None,None,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "portfolio"
#                          ("portfolio_id" bigint,  "owner_id" str,  "pm_id" str,  "name" str,  "created_at" str,  "updated_at" str,  "pm_company_id" bigint,  "escalation_contact_list" str,  "escalation_failed_email_list" str,  "job_contact_group" str,  "emergency_max_cost_soft" str,  "emergency_max_cost_hard" str,  "lcn_payment_method_id" str,  "max_cost_soft" str,  "max_cost_hard" str,  "use_default_automation" bigint,  "default_access_instructions" str,  "no_access_instructions" str,  "default_notification_group_id" str,  "inherits_vendor_priorities" str,  "lcn_opt_out" bigint,  "troubleshooting_flow_id" str,  "property_count" bigint,  "pm" str,
#                          );
#
#
#                     INSERT INTO
#                         "portfolio"
#                     ("portfolio_id","owner_id","pm_id","name","created_at","updated_at","pm_company_id","escalation_contact_list","escalation_failed_email_list","job_contact_group","emergency_max_cost_soft","emergency_max_cost_hard","lcn_payment_method_id","max_cost_soft","max_cost_hard","use_default_automation","default_access_instructions","no_access_instructions","default_notification_group_id","inherits_vendor_priorities","lcn_opt_out","troubleshooting_flow_id","property_count","pm",)
#                     VALUES
#                     (3,None,None,eos,2020-09-04 13:43:51,2020-09-04 13:43:51,1,None,None,None,None,None,None,None,None,1,None,None,None,True,None,None,5,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "company"
#                          ("company_id" bigint,  "name" str,  "created_at" str,  "updated_at" str,  "company_type" str,  "critical_note" str,  "address1" str,  "address2" str,  "city" str,  "state" str,  "zip" str,  "timezone" str,  "site_url" str,  "is_active" bigint,  "referral_company_id" str,  "review_url" str,  "portal_color" str,  "logo_url" str,  "email_template_id" str,  "primary_user_id" bigint,  "creator_id" str,  "job_count" bigint,  "referral_code" str,  "ar" str,
#                          );
#
#
#                     INSERT INTO
#                         "company"
#                     ("company_id","name","created_at","updated_at","company_type","critical_note","address1","address2","city","state","zip","timezone","site_url","is_active","referral_company_id","review_url","portal_color","logo_url","email_template_id","primary_user_id","creator_id","job_count","referral_code","ar",)
#                     VALUES
#                     (1,Gordon Test Co.,2020-09-04 13:43:34,2020-09-04 13:43:34,pm,None,1818 State Route 3,None,Fulton,NY,13069,America/New_York,None,1,None,None,None,None,None,2,None,17,cJinsNucsB,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "payment_methods"
#                          ("payment_method_id" bigint,  "relation_id" bigint,  "relation_type" str,  "type" str,  "last_four" str,  "is_primary" str,  "created_at" str,  "updated_at" str,  "description" str,  "processor" str,  "status" str,  "exp_month" str,  "exp_year" str,  "deleted_at" str,  "delete_reason" str,  "latchel_fingerprint" str,
#                          );
#
#
#                     INSERT INTO
#                         "payment_methods"
#                     ("payment_method_id","relation_id","relation_type","type","last_four","is_primary","created_at","updated_at","description","processor","status","exp_month","exp_year","deleted_at","delete_reason","latchel_fingerprint",)
#                     VALUES
#                     (1,1,Latchel\Company,card,7519,None,2020-09-04 13:43:34,2020-09-04 13:43:34,None,stripe,approved,None,None,None,None,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "settings"
#                          ("pm_company_settings_id" bigint,  "pm_company_id" bigint,  "send_invoice" bigint,  "invoice_recipient" str,  "invoice_email" str,  "ops_id" str,  "slug" str,  "created_at" str,  "updated_at" str,  "assigned_number" str,  "escalation_contact_list" str,  "escalation_failed_email_list" str,  "job_contact_group" str,  "integration_app_slug" str,  "emergency_max_cost_soft" str,  "emergency_max_cost_hard" str,  "troubleshooting_flow_id" str,  "onboard_step" str,  "subscription_payment_method_id" str,  "lcn_payment_method_id" bigint,  "max_cost_soft" str,  "max_cost_hard" str,  "use_default_automation" bigint,  "disable_property_creation" bigint,  "default_access_instructions" str,  "default_notification_group_id" str,  "disable_tenant_creation" bigint,  "emergency_temp_high" str,  "emergency_temp_low" str,  "emergency_temp_high_disabilities" str,  "emergency_temp_low_disabilities" str,  "has_pw_integration" str,  "has_3rd_party_integration" str,
#                          );
#
#
#                     INSERT INTO
#                         "settings"
#                     ("pm_company_settings_id","pm_company_id","send_invoice","invoice_recipient","invoice_email","ops_id","slug","created_at","updated_at","assigned_number","escalation_contact_list","escalation_failed_email_list","job_contact_group","integration_app_slug","emergency_max_cost_soft","emergency_max_cost_hard","troubleshooting_flow_id","onboard_step","subscription_payment_method_id","lcn_payment_method_id","max_cost_soft","max_cost_hard","use_default_automation","disable_property_creation","default_access_instructions","default_notification_group_id","disable_tenant_creation","emergency_temp_high","emergency_temp_low","emergency_temp_high_disabilities","emergency_temp_low_disabilities","has_pw_integration","has_3rd_party_integration",)
#                     VALUES
#                     (1,1,1,None,None,None,gordon-test-co-,2020-09-04 13:43:34,2020-09-04 13:43:34,None,None,None,None,None,None,None,None,None,None,1,None,None,1,None,None,None,None,None,None,None,None,None,None,)
#
#
#                          CREATE TABLE IF NOT EXISTS
#                          "state"
#                          ("state_id" bigint,  "name" str,  "description" str,  "is_visible" bigint,  "flow_type" str,
#                          );
#
#
#                     INSERT INTO
#                         "state"
#                     ("state_id","name","description","is_visible","flow_type",)
#                     VALUES
#                     (3,Finding Vendor,None,1,job,)
